# %% [markdown]
# <a href="https://colab.research.google.com/github/jeevan-tt/Playground/blob/master/Machine_learning_day_2Jeevan_tt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
link=r'C:\Users\ELCOT\Desktop\SUV_CAR.csv'
suv=pandas.read_csv(link)
print(suv)
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
print(suv.shape)
# Out:
# (400, 3)

# %%
print(suv.head(2))
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0

# %%
print(suv.head(5))
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
print(suv.head(300))
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 295   36            63000          0
# 296   42            73000          1
# 297   43           112000          1
# 298   45            79000          0
# 299   46           117000          1
#
# [300 rows x 3 columns]

# %%
print(suv.dtypes)
# Out:
# Age                int64
# EstimatedSalary    int64
# Purchased          int64
# dtype: object

# %%
suv.groupby('EstimatedSalary').size()
# Out:
# EstimatedSalary
# 15000     4
# 16000     2
# 17000     3
# 18000     4
# 19000     2
#          ..
# 146000    2
# 147000    1
# 148000    1
# 149000    2
# 150000    2
# Length: 117, dtype: int64

# %%
suv.groupby('Purchased').size()
# Out:
# Purchased
# 0    257
# 1    143
# dtype: int64

# %%
import matplotlib.pyplot as plt
suv.plot(kind = 'box' ,subplots = 1, layout=(2,2), sharex =False, sharey = False)
plt.show()

# %%
import matplotlib.pyplot as plt
suv.plot(subplots = True, layout = (2,2), )
plt.show()

# %%
import matplotlib.pyplot as plt
suv.plot()
plt.show()
